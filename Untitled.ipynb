# %%
# !pip list
# Out:
# Package              Version
# -------------------- ---------
# anyio                3.6.1
# argcomplete          1.12.3
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.8
# attrs                22.1.0
# backcall             0.2.0
# Beaker               1.10.0
# beautifulsoup4       4.11.0
# bleach               5.0.1
# blivet               3.4.4
# blivet-gui           2.3.0
# Brlapi               0.8.2
# cffi                 1.15.0
# chardet              4.0.0
# charset-normalizer   2.0.4
# chrome-gnome-shell   0.0.0
# click                8.0.1
# cryptography         3.4.7
# cupshelpers          1.0
# dasbus               1.6
# dbus-python          1.2.18
# debugpy              1.6.3
# decorator            5.0.9
# defusedxml           0.7.1
# distro               1.6.0
# entrypoints          0.4
# et-xmlfile           1.1.0
# executing            1.1.1
# fastjsonschema       2.16.2
# fedora-third-party   0.8
# fros                 1.1
# gpg                  1.15.1
# humanize             0.5.1
# idna                 3.2
# ipykernel            6.16.0
# ipython              8.5.0
# ipython_genutils     0.1.0
# ipywidgets           8.0.2
# jedi                 0.18.1
# Jinja2               3.1.2
# jsonschema           4.16.0
# jupyter              1.0.0
# jupyter_client       7.4.2
# jupyter-console      6.4.4
# jupyter-core         4.11.1
# jupyter-server       1.21.0
# jupyterlab-pygments  0.2.2
# jupyterlab-widgets   3.0.3
# langtable            0.0.59
# libcomps             0.1.18
# lxml                 4.6.5
# Mako                 1.1.4
# Markdown             3.3.7
# MarkupSafe           2.0.0
# matplotlib-inline    0.1.6
# mistune              2.0.4
# nbclassic            0.4.5
# nbclient             0.7.0
# nbconvert            7.2.1
# nbformat             5.7.0
# nest-asyncio         1.5.6
# nftables             0.1
# notebook             6.5.1
# notebook-shim        0.1.0
# numpy                1.23.4
# olefile              0.46
# openpyxl             3.0.10
# packaging            21.3
# pandas               1.5.1
# pandocfilters        1.5.0
# parso                0.8.3
# Paste                3.5.0
# patool               1.12
# pexpect              4.8.0
# pickleshare          0.7.5
# pid                  2.2.3
# Pillow               8.3.2
# pip                  21.2.3
# ply                  3.11
# productmd            1.33
# prometheus-client    0.15.0
# prompt-toolkit       3.0.31
# psutil               5.9.2
# ptyprocess           0.6.0
# pure-eval            0.2.2
# pwquality            1.4.4
# pycairo              1.20.1
# pycparser            2.20
# pycrypto             2.6.1
# pycups               2.0.1
# pycurl               7.44.1
# pyenchant            3.2.2
# Pygments             2.13.0
# PyGObject            3.42.0
# pykickstart          3.34
# pyOpenSSL            21.0.0
# pyparsing            2.4.7
# pyparted             3.12.0
# pyrsistent           0.18.1
# PySocks              1.7.1
# python-augeas        1.1.0
# python-dateutil      2.8.2
# python-meh           0.50
# pytz                 2022.5
# pyudev               0.22.0
# pyxdg                0.27
# PyYAML               5.4.1
# pyzmq                24.0.1
# qtconsole            5.3.2
# QtPy                 2.2.1
# regex                2022.9.13
# requests             2.27.1
# requests-file        1.5.1
# requests-ftp         0.3.1
# rpm                  4.17.1
# selinux              3.3
# Send2Trash           1.8.0
# sepolicy             3.3
# setools              4.4.0
# setuptools           57.4.0
# simpleaudio          1.0.4
# simpleline           1.8.2
# six                  1.16.0
# sniffio              1.3.0
# sos                  4.2
# soupsieve            2.3.1
# stack-data           0.5.1
# systemd-python       234
# Tempita              0.5.2
# terminado            0.16.0
# tinycss2             1.1.1
# tornado              6.2
# traitlets            5.4.0
# urllib3              1.26.7
# wcwidth              0.2.5
# webencodings         0.5.1
# websocket-client     1.4.1
# widgetsnbextension   4.0.3

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.7 MB)
#      |████████████████████████████████| 33.7 MB 78 kB/s  eta 0:00:01    |███████▎                        | 7.6 MB 578 kB/s eta 0:00:46     |████████████████████████▌       | 25.8 MB 788 kB/s eta 0:00:10
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in /home/Nighthawk/.local/lib/python3.10/site-packages (from scipy) (1.23.4)
# Installing collected packages: scipy
# Successfully installed scipy-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm
import seaborn as sns
import sklearn
import matplotib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 import statsmodels.api as sm
#       2 import seaborn as sns
#       3 import sklearn
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
# !pip list
# Out:
# Package              Version
# -------------------- ---------
# anyio                3.6.1
# argcomplete          1.12.3
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.8
# attrs                22.1.0
# backcall             0.2.0
# Beaker               1.10.0
# beautifulsoup4       4.11.0
# bleach               5.0.1
# blivet               3.4.4
# blivet-gui           2.3.0
# Brlapi               0.8.2
# cffi                 1.15.0
# chardet              4.0.0
# charset-normalizer   2.0.4
# chrome-gnome-shell   0.0.0
# click                8.0.1
# cryptography         3.4.7
# cupshelpers          1.0
# dasbus               1.6
# dbus-python          1.2.18
# debugpy              1.6.3
# decorator            5.0.9
# defusedxml           0.7.1
# distro               1.6.0
# entrypoints          0.4
# et-xmlfile           1.1.0
# executing            1.1.1
# fastjsonschema       2.16.2
# fedora-third-party   0.8
# fros                 1.1
# gpg                  1.15.1
# humanize             0.5.1
# idna                 3.2
# ipykernel            6.16.0
# ipython              8.5.0
# ipython_genutils     0.1.0
# ipywidgets           8.0.2
# jedi                 0.18.1
# Jinja2               3.1.2
# jsonschema           4.16.0
# jupyter              1.0.0
# jupyter_client       7.4.2
# jupyter-console      6.4.4
# jupyter-core         4.11.1
# jupyter-server       1.21.0
# jupyterlab-pygments  0.2.2
# jupyterlab-widgets   3.0.3
# langtable            0.0.59
# libcomps             0.1.18
# lxml                 4.6.5
# Mako                 1.1.4
# Markdown             3.3.7
# MarkupSafe           2.0.0
# matplotlib-inline    0.1.6
# mistune              2.0.4
# nbclassic            0.4.5
# nbclient             0.7.0
# nbconvert            7.2.1
# nbformat             5.7.0
# nest-asyncio         1.5.6
# nftables             0.1
# notebook             6.5.1
# notebook-shim        0.1.0
# numpy                1.23.4
# olefile              0.46
# openpyxl             3.0.10
# packaging            21.3
# pandas               1.5.1
# pandocfilters        1.5.0
# parso                0.8.3
# Paste                3.5.0
# patool               1.12
# pexpect              4.8.0
# pickleshare          0.7.5
# pid                  2.2.3
# Pillow               8.3.2
# pip                  21.2.3
# ply                  3.11
# productmd            1.33
# prometheus-client    0.15.0
# prompt-toolkit       3.0.31
# psutil               5.9.2
# ptyprocess           0.6.0
# pure-eval            0.2.2
# pwquality            1.4.4
# pycairo              1.20.1
# pycparser            2.20
# pycrypto             2.6.1
# pycups               2.0.1
# pycurl               7.44.1
# pyenchant            3.2.2
# Pygments             2.13.0
# PyGObject            3.42.0
# pykickstart          3.34
# pyOpenSSL            21.0.0
# pyparsing            2.4.7
# pyparted             3.12.0
# pyrsistent           0.18.1
# PySocks              1.7.1
# python-augeas        1.1.0
# python-dateutil      2.8.2
# python-meh           0.50
# pytz                 2022.5
# pyudev               0.22.0
# pyxdg                0.27
# PyYAML               5.4.1
# pyzmq                24.0.1
# qtconsole            5.3.2
# QtPy                 2.2.1
# regex                2022.9.13
# requests             2.27.1
# requests-file        1.5.1
# requests-ftp         0.3.1
# rpm                  4.17.1
# scipy                1.9.3
# selinux              3.3
# Send2Trash           1.8.0
# sepolicy             3.3
# setools              4.4.0
# setuptools           57.4.0
# simpleaudio          1.0.4
# simpleline           1.8.2
# six                  1.16.0
# sniffio              1.3.0
# sos                  4.2
# soupsieve            2.3.1
# stack-data           0.5.1
# systemd-python       234
# Tempita              0.5.2
# terminado            0.16.0
# tinycss2             1.1.1
# tornado              6.2
# traitlets            5.4.0
# urllib3              1.26.7
# wcwidth              0.2.5
# webencodings         0.5.1
# websocket-client     1.4.1
# widgetsnbextension   4.0.3

# %%
pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      |████████████████████████████████| 30.5 MB 97 kB/s  eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/Nighthawk/.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/Nighthawk/.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.9.3)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 316 kB/s eta 0:00:01
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
#     Running setup.py install for sklearn ... done
# Successfully installed joblib-1.2.0 scikit-learn-1.1.2 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 123 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in /home/Nighthawk/.local/lib/python3.10/site-packages (from matplotlib) (1.23.4)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
#      |████████████████████████████████| 295 kB 92 kB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.10/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib64/python3.10/site-packages (from matplotlib) (8.3.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.4-py3-none-any.whl (960 kB)
#      |████████████████████████████████| 960 kB 61 kB/s eta 0:00:011
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 122 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.5 cycler-0.11.0 fonttools-4.37.4 kiwisolver-1.4.4 matplotlib-3.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 205 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /home/Nighthawk/.local/lib/python3.10/site-packages (from seaborn) (1.23.4)
# Collecting matplotlib!=3.6.1,>=3.1
#   Downloading matplotlib-3.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 311 kB/s eta 0:00:01    |█████▏                          | 1.9 MB 270 kB/s eta 0:00:37
# Requirement already satisfied: pandas>=0.25 in /home/Nighthawk/.local/lib/python3.10/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib64/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/Nighthawk/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.37.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/Nighthawk/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/Nighthawk/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/Nighthawk/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /home/Nighthawk/.local/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: matplotlib, seaborn
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.1
#     Uninstalling matplotlib-3.6.1:
#       Successfully uninstalled matplotlib-3.6.1
# Successfully installed matplotlib-3.6.0 seaborn-0.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade --no-deps statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 184 kB/s eta 0:00:01
# Installing collected packages: statsmodels
# Successfully installed statsmodels-0.13.2
# Note: you may need to restart the kernel to use updated packages.
